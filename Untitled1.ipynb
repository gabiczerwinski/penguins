# %% [markdown]
# <a href="https://colab.research.google.com/github/gabiczerwinski/penguins/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/chiharuishida/Tutorialdata/main/ad_dataset_withheaders.csv"
ad = pd.read_csv(url)

# %%
ad.head(10)
# Out:
#    Site_Time  Age  DailyTime  Gender AdClicking
# 0      68.95   35     256.09  Female         No
# 1      80.23   31     193.77    Male         No
# 2      69.47   26     236.50  Female         No
# 3      74.15   29     245.89    Male         No
# 4      68.37   35     225.58  Female         No
# 5      59.99   23     226.74    Male         No
# 6      88.91   33     208.36  Female         No
# 7      66.00   48     131.76    Male        Yes
# 8      74.53   30     221.51    Male         No
# 9      69.88   20     183.82    Male         No

# %%
ad.describe()
# Out:
#          Site_Time          Age    DailyTime
# count  1000.000000  1000.000000  1000.000000
# mean     65.000200    36.009000   180.000100
# std      15.853615     8.785562    43.902339
# min      32.600000    19.000000   104.780000
# 25%      51.360000    29.000000   138.830000
# 50%      68.215000    35.000000   183.130000
# 75%      78.547500    42.000000   218.792500
# max      91.430000    61.000000   269.960000

# %%
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Site_Time   1000 non-null   float64
#  1   Age         1000 non-null   int64
#  2   DailyTime   1000 non-null   float64
#  3   Gender      1000 non-null   object
#  4   AdClicking  1000 non-null   object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 39.2+ KB

# %%
ad['Gender'].value_counts()
# Out:
# Female    519
# Male      481
# Name: Gender, dtype: int64

# %%
ad.corr()
# Out:
#            Site_Time       Age  DailyTime
# Site_Time   1.000000 -0.331513   0.518658
# Age        -0.331513  1.000000  -0.367209
# DailyTime   0.518658 -0.367209   1.000000

# %%
sns.heatmap(ad.corr(), annot=True)

# %%
sns.heatmap(ad.corr(), cmap="YlGnBu")

# %%
sns.pairplot(ad)

# %%
sns.scatterplot(x="Age", y="Site_Time", data=ad)

# %%
sns.lmplot(x = "Age", y = "DailyTime", data = ad)

# %%
sns.scatterplot(x="Site_Time", y="Age", hue="AdClicking", data=ad)

# %%
sns.lmplot(x = "Site_Time", y = "Age", hue="AdClicking", data = ad)

# %%
sns.countplot(x='DailyTime', data=ad)

# %%
sns.countplot(x='DailyTime', data=ad, color='b')

# %%
ad_dailytime=ad.groupby("DailyTime")
ad_dailytime.mean()
# Out:
#            Site_Time   Age
# DailyTime
# 104.78         59.59  42.0
# 105.00         62.06  44.0
# 105.04         63.37  43.0
# 105.15         57.76  41.0
# 105.22         63.89  40.0
# ...              ...   ...
# 259.76         68.41  38.0
# 261.02         77.07  40.0
# 261.52         70.39  32.0
# 267.01         67.64  35.0
# 269.96         57.05  41.0
#
# [966 rows x 2 columns]

# %%
sns.boxplot(x="DailyTime", y="AdClicking", data=ad)

# %%
sns.boxplot(x="Gender", y="Site_Time", hue="AdClicking", data=ad)

# %%
ad_top3_ad = ad.nlargest(3, "Site_Time")
ad_top3_ad
# Out:
#      Site_Time  Age  DailyTime  Gender AdClicking
# 533      91.43   39     209.91    Male         No
# 860      91.37   45     182.65    Male        Yes
# 927      91.15   38     184.98  Female         No
